# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv')

# %%
df.shape
# Out:
# (88883, 85)

# %%
Survey = df.drop(df.index[30000:], inplace=True)

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 2           3  I am not primarily a developer, but I write co...      Yes
# 5           6  I am not primarily a developer, but I write co...      Yes
# 6           7                     I am a developer by profession       No
# 7           8                        I code primarily as a hobby      Yes
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 2                    Never  The quality of OSS and closed source software ...
# 5                    Never  The quality of OSS and closed source software ...
# 6                    Never  The quality of OSS and closed source software ...
# 7  Less than once per year  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.to_csv('SurveyList.csv')

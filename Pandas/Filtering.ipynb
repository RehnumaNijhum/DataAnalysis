# %%
import pandas as pd

# %%
Dataset = pd.read_csv("Social_Network_Ads.csv")

# %%
Dataset.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
Dataset.shape
# Out:
# (400, 5)

# %%
type(True)
# Out:
# bool

# %%
#by loop
PurchasedResult = []
for length in Dataset.Purchased:
    if length > 0:
        PurchasedResult.append(True)
    else:
        PurchasedResult.append(False)

# %%
PurchasedResult[0:20]
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True]

# %%
#filtering only purchased data
Dataset[Dataset.Purchased >0]
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 7    15694829  Female   32           150000          1
# 16   15733883    Male   47            25000          1
# 17   15617482    Male   45            26000          1
# 18   15704583    Male   46            28000          1
# 19   15621083  Female   48            29000          1
# ..        ...     ...  ...              ...        ...
# 393  15635893    Male   60            42000          1
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 399  15594041  Female   49            36000          1
#
# [143 rows x 5 columns]

# %%
#muliple filtering
Dataset[(Dataset.Gender == 'Female') & (Dataset.Purchased > 0)]
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 7    15694829  Female   32           150000          1
# 19   15621083  Female   48            29000          1
# 21   15736760  Female   47            49000          1
# 23   15599081  Female   45            22000          1
# 27   15633531  Female   47            30000          1
# ..        ...     ...  ...              ...        ...
# 389  15668521  Female   48            35000          1
# 392  15748589  Female   45            45000          1
# 395  15691863  Female   46            41000          1
# 397  15654296  Female   50            20000          1
# 399  15594041  Female   49            36000          1
#
# [77 rows x 5 columns]

# %%
#for multiple values
Dataset[Dataset.Age.isin([25,32,48,45])]
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 7    15694829  Female   32           150000          1
# 8    15600575    Male   25            33000          0
# 13   15704987    Male   32            18000          0
# 17   15617482    Male   45            26000          1
# 19   15621083  Female   48            29000          1
# 20   15649487    Male   45            22000          1
# 22   15714658    Male   48            41000          1
# 23   15599081  Female   45            22000          1
# 46   15798850    Male   25            79000          0
# 59   15789109  Female   32           117000          0
# 61   15673619    Male   25            87000          0
# 63   15583681    Male   32           120000          1
# 70   15756932    Male   25            80000          0
# 74   15592877    Male   32            18000          0
# 102  15584545  Female   32            86000          0
# 159  15598840  Female   32           135000          1
# ...

# %%
# Dropping row or column "axis = 0" is row and "axis = 1" column
Dataset.drop('Age',axis = 1).head()
# Out:
#     User ID  Gender  EstimatedSalary  Purchased
# 0  15624510    Male            19000          0
# 1  15810944    Male            20000          0
# 2  15668575  Female            43000          0
# 3  15603246  Female            57000          0
# 4  15804002    Male            76000          0

# %%
Dataset.drop(0,axis = 0).head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0
# 5  15728773    Male   27            58000          0

# %%
# Using String method
Dataset.Gender.str.upper()
# Out:
# 0        MALE
# 1        MALE
# 2      FEMALE
# 3      FEMALE
# 4        MALE
#         ...
# 395    FEMALE
# 396      MALE
# 397    FEMALE
# 398      MALE
# 399    FEMALE
# Name: Gender, Length: 400, dtype: object

# %%
#changing data type
Dataset['EstimatedSalary'] = Dataset.EstimatedSalary.astype(float)

# %%
Dataset.dtypes
# Out:
# User ID              int64
# Gender              object
# Age                  int64
# EstimatedSalary    float64
# Purchased            int64
# dtype: object

# %%
Dataset.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19          19000.0          0
# 1  15810944    Male   35          20000.0          0
# 2  15668575  Female   26          43000.0          0
# 3  15603246  Female   27          57000.0          0
# 4  15804002    Male   19          76000.0          0

# %%
#changing Data type boolen to int
Dataset.Gender.str.contains('Female').astype(int).head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    1
# 4    0
# Name: Gender, dtype: int64

# %%
# groupby method
Dataset[Dataset.Gender == 'Male'].EstimatedSalary.mean()
# Out:
# 67642.85714285714

# %%
Dataset.groupby('Gender').EstimatedSalary.max()
# Out:
# Gender
# Female    150000.0
# Male      150000.0
# Name: EstimatedSalary, dtype: float64

# %%
Dataset.groupby('Gender').EstimatedSalary.agg(['count','min', 'max', 'mean'])
# Out:
#         count      min       max          mean
# Gender
# Female    204  15000.0  150000.0  71759.803922
# Male      196  15000.0  150000.0  67642.857143

# %%
#Explore pandas series
Dataset.Age.describe()
# Out:
# count    400.000000
# mean      37.655000
# std       10.482877
# min       18.000000
# 25%       29.750000
# 50%       37.000000
# 75%       46.000000
# max       60.000000
# Name: Age, dtype: float64

# %%
Dataset.Age.value_counts()
# Out:
# 35    32
# 37    20
# 26    16
# 41    16
# 42    16
# 39    15
# 40    15
# 48    14
# 47    14
# 27    13
# 38    13
# 28    12
# 36    12
# 46    12
# 31    11
# 30    11
# 49    10
# 29    10
# 33     9
# 32     9
# 24     9
# 59     7
# 19     7
# 45     7
# 20     7
# 60     7
# 34     6
# 23     6
# 52     6
# 25     6
# 58     6
# 53     5
# 57     5
# 22     5
# 18     5
# 21     4
# 50     4
# 54     4
# 55     3
# 56     3
# 51     3
# 43     3
# 44     2
# Name: Age, dtype: int64

# %%
# showing percentage of every value
Dataset.Age.value_counts(normalize=True)
# Out:
# 35    0.0800
# 37    0.0500
# 26    0.0400
# 41    0.0400
# 42    0.0400
# 39    0.0375
# 40    0.0375
# 48    0.0350
# 47    0.0350
# 27    0.0325
# 38    0.0325
# 28    0.0300
# 36    0.0300
# 46    0.0300
# 31    0.0275
# 30    0.0275
# 49    0.0250
# 29    0.0250
# 33    0.0225
# 32    0.0225
# 24    0.0225
# 59    0.0175
# 19    0.0175
# 45    0.0175
# 20    0.0175
# 60    0.0175
# 34    0.0150
# 23    0.0150
# 52    0.0150
# 25    0.0150
# 58    0.0150
# 53    0.0125
# 57    0.0125
# 22    0.0125
# 18    0.0125
# 21    0.0100
# 50    0.0100
# 54    0.0100
# 55    0.0075
# 56    0.0075
# 51    0.0075
# 43    0.0075
# 44    0.0050
# Name: Age, dtype: float64

# %%
Dataset.Age.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#Find and remove duplicate row
Dataset.rename({'User ID':'UserID'}, axis = 1, inplace = True)

# %%
Dataset.UserID.duplicated().sum()
# Out:
# 0

# %%
#to show the duplicated datafream
Dataset.loc[Dataset.UserID.duplicated(), :]
# Out:
# Empty DataFrame
# Columns: [UserID, Gender, Age, EstimatedSalary, Purchased]
# Index: []

# %%
#remove duplicate
Dataset.UserID.drop_duplicates()
# Out:
# 0      15624510
# 1      15810944
# 2      15668575
# 3      15603246
# 4      15804002
#          ...
# 395    15691863
# 396    15706071
# 397    15654296
# 398    15755018
# 399    15594041
# Name: UserID, Length: 400, dtype: int64

# %%
#remove duplicate from data fream 
Dataset.drop_duplicates()
# Out:
#        UserID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
#Changing disply option
pd.set_option('display.max_rows',None)

# %%
Dataset
# Out:
#        UserID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# 5    15728773    Male   27            58000          0
# 6    15598044  Female   27            84000          0
# 7    15694829  Female   32           150000          1
# 8    15600575    Male   25            33000          0
# 9    15727311  Female   35            65000          0
# 10   15570769  Female   26            80000          0
# 11   15606274  Female   26            52000          0
# 12   15746139    Male   20            86000          0
# 13   15704987    Male   32            18000          0
# 14   15628972    Male   18            82000          0
# 15   15697686    Male   29            80000          0
# ...

# %%
#to go back previous display
pd.reset_option('display.max_rows')

# %%
Dataset
# Out:
#        UserID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
pd.__version__
# Out:
# '1.5.0'

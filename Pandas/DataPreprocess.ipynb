# %%
import pandas as pd

# %%
Dataset = pd.read_csv('kidney_disease.csv')

# %%
Dataset.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
Dataset.shape
# Out:
# (400, 26)

# %%
#checking null values
Dataset.isnull().sum()
# Out:
# id                  0
# age                 9
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
#checking all data fream of null values
Dataset[Dataset.isnull()]
# Out:
#      id  age  bp  sg  al  su  rbc   pc  pcc   ba  ...  pcv   wc   rc  htn  \
# 0   NaN  NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN
# 1   NaN  NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN
# 2   NaN  NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN
# 3   NaN  NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN
# 4   NaN  NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN
# ..   ..  ...  ..  ..  ..  ..  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 395 NaN  NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN
# 396 NaN  NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN
# 397 NaN  NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN
# 398 NaN  NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN
# 399 NaN  NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN
#
#       dm  cad appet   pe  ane classification
# ...

# %%
#checking null values for a spacific column
Dataset[Dataset.age.isnull()]
# Out:
#       id  age     bp     sg   al   su       rbc        pc         pcc  \
# 30    30  NaN   70.0    NaN  NaN  NaN       NaN       NaN  notpresent
# 73    73  NaN  100.0  1.015  2.0  0.0  abnormal  abnormal  notpresent
# 112  112  NaN   60.0  1.015  3.0  0.0  abnormal  abnormal  notpresent
# 116  116  NaN   70.0  1.015  4.0  0.0  abnormal    normal  notpresent
# 117  117  NaN   70.0  1.020  0.0  0.0       NaN       NaN  notpresent
# 169  169  NaN   70.0  1.010  0.0  2.0       NaN    normal  notpresent
# 191  191  NaN   70.0  1.010  3.0  0.0    normal    normal  notpresent
# 203  203  NaN   90.0    NaN  NaN  NaN       NaN       NaN  notpresent
# 268  268  NaN   80.0    NaN  NaN  NaN       NaN       NaN  notpresent
#
#              ba  ...  pcv    wc   rc  htn    dm  cad appet   pe  ane  \
# 30   notpresent  ...  NaN   NaN  NaN  yes   yes   no  good   no   no
# 73   notpresent  ...   14  6300  NaN  yes    no   no  good  yes  yes
# ...

# %%
#drop row if any of this has null value
Dataset.dropna(how = 'any')
# Out:
#       id   age    bp     sg   al   su       rbc        pc         pcc  \
# 3      3  48.0  70.0  1.005  4.0  0.0    normal  abnormal     present
# 9      9  53.0  90.0  1.020  2.0  0.0  abnormal  abnormal     present
# 11    11  63.0  70.0  1.010  3.0  0.0  abnormal  abnormal     present
# 14    14  68.0  80.0  1.010  3.0  2.0    normal  abnormal     present
# 20    20  61.0  80.0  1.015  2.0  0.0  abnormal  abnormal  notpresent
# ..   ...   ...   ...    ...  ...  ...       ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0    normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0    normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0    normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0    normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0    normal    normal  notpresent
#
#              ba  ...  pcv     wc   rc  htn   dm  cad appet   pe  ane  \
# ...

# %%
#drop row when all has null value
Dataset.dropna(how = 'all')
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0    notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# ...

# %%
#drop row for spasific column
Dataset.dropna(subset=['age','bp'], how = 'any')
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0    notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# ...

# %%
#indexing
#select spesific row and all column
Dataset.loc[1, : ]
# Out:
# id                         1
# age                      7.0
# bp                      50.0
# sg                      1.02
# al                       4.0
# su                       0.0
# rbc                      NaN
# pc                    normal
# pcc               notpresent
# ba                notpresent
# bgr                      NaN
# bu                      18.0
# sc                       0.8
# sod                      NaN
# pot                      NaN
# hemo                    11.3
# pcv                       38
# wc                      6000
# rc                       NaN
# htn                       no
# dm                        no
# cad                       no
# appet                   good
# pe                        no
# ane                       no
# classification           ckd
# Name: 1, dtype: object

# %%
#select all rows but specific colum
Dataset.loc[  : ,'pc']
# Out:
# 0        normal
# 1        normal
# 2        normal
# 3      abnormal
# 4        normal
#          ...
# 395      normal
# 396      normal
# 397      normal
# 398      normal
# 399      normal
# Name: pc, Length: 400, dtype: object

# %%
#for multiple columns
Dataset.loc[ : ,['age','bp','pc','hemo']]
# Out:
#       age    bp        pc  hemo
# 0    48.0  80.0    normal  15.4
# 1     7.0  50.0    normal  11.3
# 2    62.0  80.0    normal   9.6
# 3    48.0  70.0  abnormal  11.2
# 4    51.0  80.0    normal  11.6
# ..    ...   ...       ...   ...
# 395  55.0  80.0    normal  15.7
# 396  42.0  70.0    normal  16.5
# 397  12.0  80.0    normal  15.8
# 398  17.0  60.0    normal  14.2
# 399  58.0  80.0    normal  15.8
#
# [400 rows x 4 columns]

# %%
#checking by specific value of a series
Dataset.loc[Dataset.pc=='abnormal', : ]
# Out:
#       id   age     bp     sg   al   su       rbc        pc         pcc  \
# 3      3  48.0   70.0  1.005  4.0  0.0    normal  abnormal     present
# 7      7  24.0    NaN  1.015  2.0  4.0    normal  abnormal  notpresent
# 8      8  52.0  100.0  1.015  3.0  0.0    normal  abnormal     present
# 9      9  53.0   90.0  1.020  2.0  0.0  abnormal  abnormal     present
# 10    10  50.0   60.0  1.010  2.0  4.0       NaN  abnormal     present
# ..   ...   ...    ...    ...  ...  ...       ...       ...         ...
# 242  242  69.0   70.0  1.010  4.0  3.0    normal  abnormal     present
# 244  244  64.0   90.0  1.015  3.0  2.0       NaN  abnormal     present
# 247  247  54.0   90.0  1.025  1.0  0.0    normal  abnormal  notpresent
# 248  248  59.0   70.0  1.010  1.0  3.0  abnormal  abnormal  notpresent
# 249  249  56.0   90.0  1.010  4.0  1.0    normal  abnormal     present
#
#              ba  ...  pcv     wc   rc  htn   dm  cad appet   pe  ane  \
# ...

# %%
Dataset.loc[Dataset.pc=='abnormal','appet' ]
# Out:
# 3      poor
# 7      good
# 8      good
# 9      poor
# 10     good
#        ...
# 242    good
# 244    good
# 247    poor
# 248    good
# 249    poor
# Name: appet, Length: 76, dtype: object

# %%
Dataset.loc[ :, ['age','bp','pc']]
# Out:
#       age    bp        pc
# 0    48.0  80.0    normal
# 1     7.0  50.0    normal
# 2    62.0  80.0    normal
# 3    48.0  70.0  abnormal
# 4    51.0  80.0    normal
# ..    ...   ...       ...
# 395  55.0  80.0    normal
# 396  42.0  70.0    normal
# 397  12.0  80.0    normal
# 398  17.0  60.0    normal
# 399  58.0  80.0    normal
#
# [400 rows x 3 columns]

# %%
#creating dummy variable
pd.get_dummies(Dataset.pc)
# Out:
#      abnormal  normal
# 0           0       1
# 1           0       1
# 2           0       1
# 3           1       0
# 4           0       1
# ..        ...     ...
# 395         0       1
# 396         0       1
# 397         0       1
# 398         0       1
# 399         0       1
#
# [400 rows x 2 columns]

# %%
#taking one row from dummy 
PcDummies = pd.get_dummies(Dataset.pc, prefix ='pc').iloc[ : ,1:]

# %%
# passing dummy series on a datafream
Dataset = pd.concat([Dataset,PcDummies], axis=1)

# %%
Dataset.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...    wc   rc  htn   dm  cad  appet   pe  ane classification pc_normal
# 0  ...  7800  5.2  yes  yes   no   good   no   no            ckd         1
# 1  ...  6000  NaN   no   no   no   good   no   no            ckd         1
# 2  ...  7500  NaN   no  yes   no   poor   no  yes            ckd         1
# 3  ...  6700  3.9  yes   no   no   poor  yes  yes            ckd         0
# 4  ...  7300  4.6   no   no   no   good   no   no            ckd         1
#
# [5 rows x 27 columns]

# %%
#passing a data fream on a series
#just selecting one column of dummy
pd.get_dummies(Dataset, columns = ['pc', 'appet'], drop)
# Out:
#       id   age    bp     sg   al   su     rbc         pcc          ba    bgr  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN  notpresent  notpresent  121.0
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN  notpresent  notpresent    NaN
# 2      2  62.0  80.0  1.010  2.0  3.0  normal  notpresent  notpresent  423.0
# 3      3  48.0  70.0  1.005  4.0  0.0  normal     present  notpresent  117.0
# 4      4  51.0  80.0  1.010  2.0  0.0  normal  notpresent  notpresent  106.0
# ..   ...   ...   ...    ...  ...  ...     ...         ...         ...    ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal  notpresent  notpresent  140.0
# 396  396  42.0  70.0  1.025  0.0  0.0  normal  notpresent  notpresent   75.0
# 397  397  12.0  80.0  1.020  0.0  0.0  normal  notpresent  notpresent  100.0
# 398  398  17.0  60.0  1.025  0.0  0.0  normal  notpresent  notpresent  114.0
# 399  399  58.0  80.0  1.025  0.0  0.0  normal  notpresent  notpresent  131.0
#
# ...

# %%
import pandas as pd

# %%
SurveyData = pd.read_csv('SurveyList.csv',index_col='Respondent')

# %%
SurveySchema = pd.read_csv('survey_results_schema.csv', index_col ='Column')

# %%
SurveyData.shape
# Out:
# (30000, 85)

# %%
#to diplay all column in dataframe 
pd.set_option('display.max_columns',84)

# %%
SurveyData.head()
# Out:
#             Unnamed: 0                                         MainBranch  \
# Respondent
# 1                    0             I am a student who is learning to code
# 3                    2  I am not primarily a developer, but I write co...
# 6                    5  I am not primarily a developer, but I write co...
# 7                    6                     I am a developer by profession
# 8                    7                        I code primarily as a hobby
#
#            Hobbyist              OpenSourcer  \
# Respondent
# 1               Yes                    Never
# 3               Yes                    Never
# 6               Yes                    Never
# 7                No                    Never
# 8               Yes  Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
# we will filter country, education level and programming language working with by the basis of high salary
HighSalary = (SurveyData['ConvertedComp']>70000)

# %%
SurveyData.loc[HighSalary, ['ConvertedComp','Country','EdLevel','LanguageWorkedWith']]
# Out:
#             ConvertedComp         Country  \
# Respondent
# 6                366420.0          Canada
# 9                 95179.0     New Zealand
# 13                90000.0   United States
# 16               455352.0  United Kingdom
# 22               103000.0   United States
# ...                   ...             ...
# 33189            100000.0   United States
# 33192            662796.0          Sweden
# 33199            204000.0   United States
# 33206            392544.0  United Kingdom
# 33207             75000.0   United States
#
#                                                       EdLevel  \
# Respondent
# 6                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 9           Some college/university study without earning ...
# 13                Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 16                Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 22          Some college/university study without earning ...
# ...

# %%
#filtering for specific countries
Countries = ['Bangladesh']
GetCountry = SurveyData['Country'].isin(Countries)
SurveyData.loc[GetCountry]
# Out:
#             Unnamed: 0                                         MainBranch  \
# Respondent
# 42                  41                     I am a developer by profession
# 171                169             I am a student who is learning to code
# 300                298             I am a student who is learning to code
# 324                322                     I am a developer by profession
# 690                687  I used to be a developer by profession, but no...
# ...                ...                                                ...
# 31637            31448                     I am a developer by profession
# 32133            31940                     I am a developer by profession
# 32679            32482                     I am a developer by profession
# 32833            32633                     I am a developer by profession
# 33122            32916                     I am a developer by profession
#
# ...

# %%
#flitering who use python language
#ProLanguage = ['Python']
UsePython = SurveyData['LanguageWorkedWith'].str.contains('Python', na = False)
SurveyData.loc[UsePython,['Country','ConvertedComp','LanguageWorkedWith']]
# Out:
#                    Country  ConvertedComp  \
# Respondent
# 1           United Kingdom            NaN
# 8                    India            NaN
# 9              New Zealand        95179.0
# 10                   India        13293.0
# 12                  Canada            NaN
# ...                    ...            ...
# 33199        United States       204000.0
# 33200             Slovenia            NaN
# 33202              Germany            NaN
# 33204              Nigeria            NaN
# 33208             Bulgaria            NaN
#
#                                            LanguageWorkedWith
# Respondent
# 1                             HTML/CSS;Java;JavaScript;Python
# 8           Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 9           Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 10                              C#;Go;JavaScript;Python;R;SQL
# 12           Bash/Shell/PowerShell;HTML/CSS;Java;Python;R;SQL
# ...

# %%
SurveySchema.head()
# Out:
#                                                   QuestionText
# Column
# Respondent   Randomized respondent ID number (not in order ...
# MainBranch   Which of the following options best describes ...
# Hobbyist                               Do you code as a hobby?
# OpenSourcer        How often do you contribute to open source?
# OpenSource   How do you feel about the quality of open sour...

# %%
#filtering country
